# %%
import pandas as pd

df = pd.read_csv('Student Mental Health Analysis During Online Learning.csv')
df
# Out:
#        Name  Gender  Age Education Level  Screen Time (hrs/day)  \
# 0     Aarav    Male   15         Class 8                    7.1
# 1     Meera  Female   25             MSc                    3.3
# 2    Ishaan    Male   20           BTech                    9.5
# 3    Aditya    Male   20              BA                   10.8
# 4     Anika  Female   17        Class 11                    2.8
# ..      ...     ...  ...             ...                    ...
# 995    Diya  Female   26              MA                   11.3
# 996   Aarav    Male   20           BTech                    5.5
# 997    Myra  Female   15         Class 9                    7.1
# 998    Myra  Female   20              BA                    4.4
# 999  Vihaan    Male   23              MA                   10.8
#
#      Sleep Duration (hrs)  Physical Activity (hrs/week) Stress Level  \
# 0                     8.9                           9.3       Medium
# ...

# %%
#Apakah screen time tinggi berkorelasi dengan penurunan performa akademik
#Apakah ada siswa yang memiliki waktu tidur kurang dari 7 jam
#Apakah siswa yang kurang physical Activity akan mengalami Stress Level
#Apakah ada siswa yang mengalami penurunan performa akademik
#Siswa mana yang memiliki Stress Level yang paling tinggi
#Apakah ada siswa yang memiliki Anxious Before High
